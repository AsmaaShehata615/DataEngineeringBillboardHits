# %%
! pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\fagr\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\fagr\anaconda3\lib\site-packages (from spotipy) (1.26.7)
# Requirement already satisfied: six>=1.15.0 in c:\users\fagr\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\fagr\anaconda3\lib\site-packages (from spotipy) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\fagr\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fagr\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fagr\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.2)

# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
client_id = "94c0ec47470c40ae83be5449e01dcca3"
client_secret = "dee2afe7fab9470d89e718f405687a53"
client_credentials= SpotifyClientCredentials(client_id= client_id , client_secret= client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials )

# %%
import pandas as pd 
data= pd.read_csv('artist.csv', nrows= 200
                 )

# %%
names = data['Artist']
names.values.tolist()
result= sp.search(names)
result['tracks']['items'][1]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#   'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#   'id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'name': 'Ed Sheeran',
#   'type': 'artist',
#   'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}]

# %%
#Extract Artist's uri
artists_uris = result['tracks']['items'][0]['artists'][0]['uri']
#Pull all of the artist's albums
artist_albums = sp.artist_albums(artists_uris, album_type='album')
#Store artist's albums' names' and uris in separate lists
artist_album_names = []
artist_album_uris = []
for i in range(len(artist_albums['items'])):
    artist_album_names.append(artist_albums['items'][i]['name'])
    artist_album_uris.append(artist_albums['items'][i]['uri'])
    
artist_album_names
artist_album_uris
# Out:
# ['spotify:album:5ocpnIrbBOWWpHqk2uI1pa',
#  'spotify:album:5W2wJUsVxy9l9jONK5LvGB',
#  'spotify:album:32iAEBstCjauDhyKpGjTuq',
#  'spotify:album:3oIFxDIo2fwuk4lwCmFZCx',
#  'spotify:album:5oUZ9TEZR3wOdvqzowuNwl',
#  'spotify:album:3T4tUhGYeRNVUGevb0wThu',
#  'spotify:album:0MeOIA0wwSa6nW79jy8QcZ',
#  'spotify:album:2hyDesSAYNefikDJXlqhPE',
#  'spotify:album:1xn54DMo2qIqBuMqHtUsFd',
#  'spotify:album:0Yi8StK0Si3u2bLr3Qsm2Q',
#  'spotify:album:3hA2oZbZwHU8tSPBFIZhFr',
#  'spotify:album:6NoBzYmh5gUusGPCfg0pct',
#  'spotify:album:4JUtnlZKdLr01xEIymhm0G',
#  'spotify:album:3QbPtoOWiJqZurXXxJwaOD',
#  'spotify:album:1slAnKc9Ykyght8EI9Y0dM',
#  'spotify:album:3w0VffyaakTvUtTwjPCo7Y',
#  'spotify:album:02pi98kE0nra0yBqCStzbC',
#  'spotify:album:2PNtGh8cixtb0oXjbGkUnZ',
#  'spotify:album:0W5GGnapMz0VwemQvJDqa7',
#  'spotify:album:6DpIyaMgt5p9HlGd1c0LDM']

# %%
def album_songs(uri):
    album = uri 
    spotify_albums[album] = {}
    #Create keys-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = [] 
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    #pull data on album tracks
    tracks = sp.album_tracks(album) 
    for n in range(len(tracks['items'])): 
        spotify_albums[album]['album'].append(artist_album_names[album_count]) 
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
spotify_albums = {}
album_count = 0
for i in artist_album_uris: #each album
    album_songs(i)
    print(str(artist_album_names[album_count]) + " album songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added
# Out:
# = (Christmas Edition) album songs has been added to spotify_albums dictionary
# = (Christmas Edition) album songs has been added to spotify_albums dictionary
# = album songs has been added to spotify_albums dictionary
# No.6 Collaborations Project album songs has been added to spotify_albums dictionary
# No.6 Collaborations Project album songs has been added to spotify_albums dictionary
# ÷ (Deluxe) album songs has been added to spotify_albums dictionary
# x (Wembley Edition) album songs has been added to spotify_albums dictionary
# 5 album songs has been added to spotify_albums dictionary
# x (Deluxe Edition) album songs has been added to spotify_albums dictionary
# x (Wembley Edition) album songs has been added to spotify_albums dictionary
# x (Wembley Edition) album songs has been added to spotify_albums dictionary
# x (Wembley Edition) album songs has been added to spotify_albums dictionary
# Live at the Bedford album songs has been added to spotify_albums dictionary
# Loose Change album songs has been added to spotify_albums dictionary
# + album songs has been added to spotify_albums dictionary
# + album songs has been added to spotify_albums dictionary
# + album songs has been added to spotify_albums dictionary
# + album songs has been added to spotify_albums dictionary
# + album songs has been added to spotify_albums dictionary
# No.5 Collaborations Project album songs has been added to spotify_albums dictionary

# %%
def audio_features(album):
    #Add new key-values to store audio features
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    
    track_count = 0
    for track in spotify_albums[album]['uri']:
        #pull audio features per track
        features = sp.audio_features(track)
        
        #Append to relevant key-value
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        #popularity is stored elsewhere
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %%
import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
for i in spotify_albums:
    audio_features(i)
    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 23.864405632019043 seconds
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 64.02361583709717 seconds
# 15 playlists completed
# Loop #: 15
# Elapsed Time: 93.31547522544861 seconds
# 20 playlists completed
# Loop #: 20
# Elapsed Time: 118.0599455833435 seconds

# %%
dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])
# Out:
# 329

# %%
import pandas as pd
dataframe = pd.DataFrame.from_dict(dic_df)
dataframe
# Out:
#                            album  track_number                      id  \
# 0          = (Christmas Edition)             1  0aoUM0zcu0kCX7Cv7O939I
# 1          = (Christmas Edition)             2  1vV7kax5Dtq4UYgxxyNp0i
# 2          = (Christmas Edition)             3  6UW39YshTGhjxPtTOg8Ln9
# 3          = (Christmas Edition)             4  2svoCXTQnV52hJMU4PeSok
# 4          = (Christmas Edition)             5  79g9ptkBCqwK3Iy8CWbyPf
# ..                           ...           ...                     ...
# 324  No.5 Collaborations Project             4  5KB7EYQuHd0S5WKVWpagYu
# 325  No.5 Collaborations Project             5  5rKb6l02IplvF9I0sJI9Lj
# 326  No.5 Collaborations Project             6  0UD8qgp0Fmgh79K3qeTHQh
# 327  No.5 Collaborations Project             7  4MKPqVv3FqKCZTcKHfR125
# 328  No.5 Collaborations Project             8  1SdyQYIFM05qkexCFKZxW1
#
#                                                   name  \
# 0                                      Merry Christmas
# 1                                                Tides
# 2                                              Shivers
# 3                                          First Times
# 4                                           Bad Habits
# ..                                                 ...
# 324                                  Radio (feat. JME)
# 325                    Little Lady (feat. Mikill Pane)
# 326             Drown Me Out (feat. Ghetts) - + Ghetts
# 327  Nightmares (feat. Random Impulse, Sway & Wretc...
# 328                  Goodbye to You (feat. Dot Rotten)
#
#                                       uri  acousticness  danceability  energy  \
# 0    spotify:track:0aoUM0zcu0kCX7Cv7O939I        0.2430         0.594   0.935
# 1    spotify:track:1vV7kax5Dtq4UYgxxyNp0i        0.0167         0.631   0.825
# 2    spotify:track:6UW39YshTGhjxPtTOg8Ln9        0.2810         0.788   0.859
# 3    spotify:track:2svoCXTQnV52hJMU4PeSok        0.8400         0.587   0.267
# 4    spotify:track:79g9ptkBCqwK3Iy8CWbyPf        0.0451         0.807   0.893
# ..                                    ...           ...           ...     ...
# 324  spotify:track:5KB7EYQuHd0S5WKVWpagYu        0.2140         0.693   0.833
# 325  spotify:track:5rKb6l02IplvF9I0sJI9Lj        0.7310         0.437   0.500
# 326  spotify:track:0UD8qgp0Fmgh79K3qeTHQh        0.0282         0.511   0.910
# 327  spotify:track:4MKPqVv3FqKCZTcKHfR125        0.1010         0.855   0.678
# 328  spotify:track:1SdyQYIFM05qkexCFKZxW1        0.2670         0.640   0.664
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0            0.000002    0.1020    -2.018       0.0357  113.990    0.602
# 1            0.000000    0.1220    -3.971       0.0433  129.942    0.427
# 2            0.000000    0.0424    -2.724       0.0856  141.020    0.822
# 3            0.000000    0.1210    -9.206       0.0349   98.845    0.352
# 4            0.000028    0.3660    -3.745       0.0347  126.011    0.537
# ..                ...       ...       ...          ...      ...      ...
# 324          0.000000    0.1170    -5.408       0.2630   99.901    0.759
# 325          0.000000    0.1570    -7.103       0.1050   85.293    0.437
# 326          0.000000    0.1270    -6.186       0.1160  140.147    0.426
# 327          0.002320    0.0964    -6.864       0.0520  120.012    0.429
# 328          0.000000    0.3290    -7.812       0.1520  140.007    0.275
#
#      popularity
# 0            67
# 1            52
# 2            56
# 3            50
# 4            54
# ..          ...
# 324          40
# 325          45
# 326          36
# 327          36
# 328          37
#
# [329 rows x 15 columns]

# %%
print(len(dataframe))
final_df = dataframe.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
print(len(final_df))
# Out:
# 329
# 118

# %%
final_df.head()
# Out:
#                     album  track_number                      id  \
# 0   = (Christmas Edition)             1  0aoUM0zcu0kCX7Cv7O939I
# 30                      =             1  2JiHR4gCDjXwYVRDmwdk95
# 31                      =             2  50nfwKoDiSYg8zOCREWAm5
# 32                      =             3  5QYnNhTKsN3kE7OaqILA1U
# 33                      =             4  3rmo8F54jFF8OgYsqTxm5d
#
#                name                                   uri  acousticness  \
# 0   Merry Christmas  spotify:track:0aoUM0zcu0kCX7Cv7O939I        0.2430
# 30            Tides  spotify:track:2JiHR4gCDjXwYVRDmwdk95        0.0167
# 31          Shivers  spotify:track:50nfwKoDiSYg8zOCREWAm5        0.2810
# 32      First Times  spotify:track:5QYnNhTKsN3kE7OaqILA1U        0.8400
# 33       Bad Habits  spotify:track:3rmo8F54jFF8OgYsqTxm5d        0.0451
#
#     danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0          0.594   0.935          0.000002    0.1020    -2.018       0.0357
# 30         0.631   0.825          0.000000    0.1220    -3.971       0.0433
# 31         0.788   0.859          0.000000    0.0424    -2.724       0.0856
# 32         0.587   0.267          0.000000    0.1210    -9.206       0.0349
# 33         0.807   0.893          0.000028    0.3660    -3.745       0.0347
#
#       tempo  valence  popularity
# 0   113.990    0.602          67
# 30  129.942    0.427          79
# 31  141.020    0.822          95
# 32   98.845    0.352          81
# 33  126.011    0.537          94

# %%
final_df.to_csv("spotify_music.csv")

# %% [markdown]
# # getting billboard hot 100

# %%
# !pip install billboard.py
# Out:
# Requirement already satisfied: billboard.py in c:\users\fagr\anaconda3\lib\site-packages (7.0.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\fagr\anaconda3\lib\site-packages (from billboard.py) (4.10.0)
# Requirement already satisfied: requests>=2.2.1 in c:\users\fagr\anaconda3\lib\site-packages (from billboard.py) (2.26.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\fagr\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->billboard.py) (2.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\fagr\anaconda3\lib\site-packages (from requests>=2.2.1->billboard.py) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fagr\anaconda3\lib\site-packages (from requests>=2.2.1->billboard.py) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fagr\anaconda3\lib\site-packages (from requests>=2.2.1->billboard.py) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\fagr\anaconda3\lib\site-packages (from requests>=2.2.1->billboard.py) (2.0.4)

# %%
Date=[]
startDate = date(2011, 1, 1)
for i in range(10):
    # reconstruct date fully
    endDate = date(startDate.year + 1, startDate.month, startDate.day)
    # replace year only
    endDate = startDate.replace(startDate.year + 1)
    Date.append(str(endDate))
    startDate=endDate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19016/4174775306.py in <module>
#       1 Date=[]
# ----> 2 startDate = date(2011, 1, 1)
#       3 for i in range(10):
#       4     # reconstruct date fully
#       5     endDate = date(startDate.year + 1, startDate.month, startDate.day)
#
# TypeError: 'str' object is not callable

# %%
Date
# Out:
# []

# %%
import billboard
import csv

chart = billboard.ChartData('hot-100', date= '2020-01-01')

f = open('hot-100.csv', 'w')

headers = 'title, artist, peakPos, lastPos, weeks, rank, date\n'
f.write(headers)

date = chart.date

while chart.previousDate:
    date = chart.date
    for song in chart:
        title = song.title
        artist = song.artist
        peakPos = str(song.peakPos)
        lastPos = str(song.lastPos)
        weeks = str(song.weeks)
        rank = str(song.rank)

        f.write('\"' + title + '\",\"' + artist.replace('Featuring', 'Feat.') + '\",' + peakPos + ',' + lastPos + ',' + weeks + ',' + rank + ',' + date + '\n')
    chart = billboard.ChartData('hot-100', chart.previousDate)
    
f.close()
